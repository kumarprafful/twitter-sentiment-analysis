# %%
import numpy as np
import pandas as pd
from nltk import word_tokenize

# %%
training = pd.read_csv("0000000000002747_training_twitter_x_y_train.csv")
testing = pd.read_csv("0000000000002747_test_twitter_x_test.csv")

# %%
training
# Out:
#                  tweet_id airline_sentiment     airline  \
# 0      567900433542488064          negative   Southwest
# 1      569989168903819264          positive   Southwest
# 2      568089179520954368          positive      United
# 3      568928195581513728          negative   Southwest
# 4      568594180014014464          negative      United
# 5      569677636613439488          negative      United
# 6      569658903044218880          negative       Delta
# 7      568542766860541952          positive       Delta
# 8      570116209263427584          negative      United
# 9      568870144891600896          positive   Southwest
# 10     567793635892174848          negative   Southwest
# 11     569879497891303424           neutral       Delta
# 12     568517827482685440          positive  US Airways
# 13     568212893012860928          negative   Southwest
# 14     569270187725160449          negative  US Airways
# 15     567816651900583936          negative  US Airways
# ...

# %%
training.columns
# Out:
# Index(['tweet_id', 'airline_sentiment', 'airline', 'airline_sentiment_gold',
#        'name', 'negativereason_gold', 'retweet_count', 'text', 'tweet_coord',
#        'tweet_created', 'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
train = training
test = testing

# %%
for x in train.columns:
    if x == 'airline_sentiment' or x=='text':
        continue
    else:
        del train[x]

# %%
for x in test.columns:
    if x=='text':
        continue
    else:
        del test[x]

# %%
train.head()
# Out:
#   airline_sentiment                                               text
# 0          negative  @SouthwestAir I am scheduled for the morning, ...
# 1          positive  @SouthwestAir seeing your workers time in and ...
# 2          positive  @united Flew ORD to Miami and back and  had gr...
# 3          negative     @SouthwestAir @dultch97 that's horse radish 😤🐴
# 4          negative  @united so our flight into ORD was delayed bec...

# %%
test.head()
# Out:
#                                                 text
# 0  @AmericanAir In car gng to DFW. Pulled over 1h...
# 1  @AmericanAir after all, the plane didn’t land ...
# 2  @SouthwestAir can't believe how many paying cu...
# 3  @USAirways I can legitimately say that I would...
# 4  @AmericanAir still no response from AA. great ...

# %%
document = []
for i in range(len(train)):
    document.append((word_tokenize(train["text"][i]), train["airline_sentiment"][i]))

# %%
document
# Out:
# [(['@',
#    'SouthwestAir',
#    'I',
#    'am',
#    'scheduled',
#    'for',
#    'the',
#    'morning',
#    ',',
#    '2',
#    'days',
#    'after',
#    'the',
#    'fact',
#    ',',
#    'yes..not',
#    'sure',
#    'why',
#    'my',
#    'evening',
#    'flight',
#    'was',
#    'the',
#    'only',
#    'one',
#    'Cancelled',
#    'Flightled'],
#   'negative'),
#  (['@',
#    'SouthwestAir',
#    'seeing',
#    'your',
#    'workers',
#    'time',
#    'in',
#    'and',
#    'time',
#    'out',
#    'going',
#    'above',
#    'and',
#    'beyond',
#    'is',
#    'why',
#    'I',
#    'love',
#    'flying',
#    'with',
#    'you',
#    'guys',
#    '.',
#    'Thank',
#    'you',
#    '!'],
#   'positive'),
#  (['@',
#    'united',
#    'Flew',
#    'ORD',
#    'to',
#    'Miami',
#    'and',
#    'back',
#    'and',
#    'had',
#    'great',
#    'crew',
#    ',',
#    'service',
#    'on',
#    'both',
#    'legs',
#    '.',
#    'THANKS'],
#   'positive'),
#  (['@',
# ...

# %%
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
from nltk.corpus import wordnet
def get_simple_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
from nltk.corpus import stopwords
import string
stops = set(stopwords.words('english'))
punctutations = list(string.punctuation)
stops.update(punctutations)

# %%
def clean_review(words):
    output_words = []
    for w in words:
        if w.lower() not in stops:
            pos = pos_tag(w)
            clean_words = lemmatizer.lemmatize(w, pos = get_simple_pos(pos[0][1]))
            output_words.append(clean_words.lower())
    
    return output_words

# %%
document
# Out:
# [(['@',
#    'SouthwestAir',
#    'I',
#    'am',
#    'scheduled',
#    'for',
#    'the',
#    'morning',
#    ',',
#    '2',
#    'days',
#    'after',
#    'the',
#    'fact',
#    ',',
#    'yes..not',
#    'sure',
#    'why',
#    'my',
#    'evening',
#    'flight',
#    'was',
#    'the',
#    'only',
#    'one',
#    'Cancelled',
#    'Flightled'],
#   'negative'),
#  (['@',
#    'SouthwestAir',
#    'seeing',
#    'your',
#    'workers',
#    'time',
#    'in',
#    'and',
#    'time',
#    'out',
#    'going',
#    'above',
#    'and',
#    'beyond',
#    'is',
#    'why',
#    'I',
#    'love',
#    'flying',
#    'with',
#    'you',
#    'guys',
#    '.',
#    'Thank',
#    'you',
#    '!'],
#   'positive'),
#  (['@',
#    'united',
#    'Flew',
#    'ORD',
#    'to',
#    'Miami',
#    'and',
#    'back',
#    'and',
#    'had',
#    'great',
#    'crew',
#    ',',
#    'service',
#    'on',
#    'both',
#    'legs',
#    '.',
#    'THANKS'],
#   'positive'),
#  (['@',
# ...

# %%
documents = []
for x in document:
    documents.append((clean_review(x[0]), x[1]))

# %%
documents
# Out:
# [(['southwestair',
#    'scheduled',
#    'morning',
#    '2',
#    'days',
#    'fact',
#    'yes..not',
#    'sure',
#    'evening',
#    'flight',
#    'one',
#    'cancelled',
#    'flightled'],
#   'negative'),
#  (['southwestair',
#    'seeing',
#    'worker',
#    'time',
#    'time',
#    'going',
#    'beyond',
#    'love',
#    'flying',
#    'guy',
#    'thank'],
#   'positive'),
#  (['united',
#    'flew',
#    'ord',
#    'miami',
#    'back',
#    'great',
#    'crew',
#    'service',
#    'leg',
#    'thanks'],
#   'positive'),
#  (['southwestair', 'dultch97', "'s", 'horse', 'radish', '😤🐴'], 'negative'),
#  (['united',
#    'flight',
#    'ord',
#    'delayed',
#    'air',
#    'force',
#    'one',
#    'last',
#    'flight',
#    'sbn',
#    '8:20',
#    '5',
#    'min',
#    'landed'],
#   'negative'),
#  (['united',
#    'load',
#    'us',
#    'flying',
#    'sardine',
#    'knew',
#    'pilot',
#    '2',
#    'hour',
#    'late',
#    'flight',
# ...

# %%
training_documents = documents

# %%
all_words = []
for doc in training_documents:
    all_words += doc[0]

# %%
import nltk

# %%
freq = nltk.FreqDist(all_words)
common = freq.most_common(3000)
features = [i[0] for i in common]

# %%
features
# Out:
# ['united',
#  'flight',
#  'usairways',
#  'americanair',
#  'southwestair',
#  'jetblue',
#  "n't",
#  "'s",
#  'get',
#  'http',
#  'hour',
#  'thanks',
#  'cancelled',
#  '...',
#  'service',
#  'customer',
#  'time',
#  'help',
#  'call',
#  'bag',
#  'plane',
#  'amp',
#  "'m",
#  'us',
#  'hold',
#  '2',
#  'thank',
#  'flights',
#  'would',
#  'still',
#  'one',
#  'make',
#  'need',
#  'gate',
#  'please',
#  'back',
#  'ca',
#  'delayed',
#  'airline',
#  'virginamerica',
#  'flightled',
#  'say',
#  'got',
#  "'ve",
#  "''",
#  'delay',
#  '``',
#  'seat',
#  'like',
#  'phone',
#  'agent',
#  'take',
#  'late',
#  'today',
#  'fly',
#  'guy',
#  'ticket',
#  'know',
#  'airport',
#  'waiting',
#  'u',
#  'could',
#  'trying',
#  'minute',
#  'change',
#  'great',
#  '3',
#  'way',
#  'going',
#  'never',
#  'go',
#  'flying',
#  'min',
#  'wait',
#  'really',
#  'day',
#  'want',
#  'home',
#  'hr',
#  "'re",
#  'tomorrow',
#  '4',
#  'weather',
#  'last',
#  'dm',
# ...

# %%
def get_feature_dict(words):
    current_features = {}
    words_set = set(words)
    for w in features:
        current_features[w] = w in words_set
    return current_features

# %%
training_data = [(get_feature_dict(doc[0]), doc[1]) for doc in training_documents]

# %% [markdown]
# # testing

# %%
test.head()
# Out:
#                                                 text
# 0  @AmericanAir In car gng to DFW. Pulled over 1h...
# 1  @AmericanAir after all, the plane didn’t land ...
# 2  @SouthwestAir can't believe how many paying cu...
# 3  @USAirways I can legitimately say that I would...
# 4  @AmericanAir still no response from AA. great ...

# %%
test_data_doc = []
for i in range(len(test)):
    test_data_doc.append((word_tokenize(test["text"][i]),))

# %%
test_data_doc
# Out:
# [(['@',
#    'AmericanAir',
#    'In',
#    'car',
#    'gng',
#    'to',
#    'DFW',
#    '.',
#    'Pulled',
#    'over',
#    '1hr',
#    'ago',
#    '-',
#    'very',
#    'icy',
#    'roads',
#    '.',
#    'On-hold',
#    'with',
#    'AA',
#    'since',
#    '1hr',
#    '.',
#    'Ca',
#    "n't",
#    'reach',
#    'arpt',
#    'for',
#    'AA2450',
#    '.',
#    'Wat',
#    '2',
#    'do',
#    '?'],),
#  (['@',
#    'AmericanAir',
#    'after',
#    'all',
#    ',',
#    'the',
#    'plane',
#    'didn',
#    '’',
#    't',
#    'land',
#    'in',
#    'identical',
#    'or',
#    'worse',
#    ')',
#    'conditions',
#    'at',
#    'GRK',
#    'according',
#    'to',
#    'METARs',
#    '.'],),
#  (['@',
#    'SouthwestAir',
#    'ca',
#    "n't",
#    'believe',
#    'how',
#    'many',
#    'paying',
#    'customers',
#    'you',
#    'left',
#    'high',
#    'and',
#    'dry',
#    'with',
#    'no',
#    'reason',
#    'for',
#    'flight',
#    'Cancelled',
# ...

# %%
test_documents = []
for x in test_data_doc:
    test_documents.append((clean_review(x[0]),))

# %%
testing_data = [(get_feature_dict(doc[0]),) for doc in test_documents]

# %%
testing_data[0]
# Out:
# ({'united': False,
#   'flight': False,
#   'usairways': False,
#   'americanair': True,
#   'southwestair': False,
#   'jetblue': False,
#   "n't": True,
#   "'s": False,
#   'get': False,
#   'http': False,
#   'hour': False,
#   'thanks': False,
#   'cancelled': False,
#   '...': False,
#   'service': False,
#   'customer': False,
#   'time': False,
#   'help': False,
#   'call': False,
#   'bag': False,
#   'plane': False,
#   'amp': False,
#   "'m": False,
#   'us': False,
#   'hold': False,
#   '2': True,
#   'thank': False,
#   'flights': False,
#   'would': False,
#   'still': False,
#   'one': False,
#   'make': False,
#   'need': False,
#   'gate': False,
#   'please': False,
#   'back': False,
#   'ca': True,
#   'delayed': False,
#   'airline': False,
#   'virginamerica': False,
#   'flightled': False,
#   'say': False,
#   'got': False,
#   "'ve": False,
#   "''": False,
#   'delay': False,
#   '``': False,
#   'seat': False,
#   'like': False,
#   'phone': False,
# ...

# %%
training_data[0]
# Out:
# ({'united': False,
#   'flight': True,
#   'usairways': False,
#   'americanair': False,
#   'southwestair': True,
#   'jetblue': False,
#   "n't": False,
#   "'s": False,
#   'get': False,
#   'http': False,
#   'hour': False,
#   'thanks': False,
#   'cancelled': True,
#   '...': False,
#   'service': False,
#   'customer': False,
#   'time': False,
#   'help': False,
#   'call': False,
#   'bag': False,
#   'plane': False,
#   'amp': False,
#   "'m": False,
#   'us': False,
#   'hold': False,
#   '2': True,
#   'thank': False,
#   'flights': False,
#   'would': False,
#   'still': False,
#   'one': True,
#   'make': False,
#   'need': False,
#   'gate': False,
#   'please': False,
#   'back': False,
#   'ca': False,
#   'delayed': False,
#   'airline': False,
#   'virginamerica': False,
#   'flightled': True,
#   'say': False,
#   'got': False,
#   "'ve": False,
#   "''": False,
#   'delay': False,
#   '``': False,
#   'seat': False,
#   'like': False,
#   'phone': False,
# ...

# %%
from nltk import NaiveBayesClassifier

# %%
classifier = NaiveBayesClassifier.train(training_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-867e2e6f99fc> in <module>()
# ----> 1 classifier = NaiveBayesClassifier.train(training_data)
#
# ~/anaconda3/lib/python3.6/site-packages/nltk/classify/naivebayes.py in train(cls, labeled_featuresets, estimator)
#     196             for fname, fval in featureset.items():
#     197                 # Increment freq(fval|label, fname)
# --> 198                 feature_freqdist[label, fname][fval] += 1
#     199                 # Record that fname can take the value fval.
#     200                 feature_values[fname].add(fval)
#
# KeyboardInterrupt:

# %%
y_pred = []
for i in range(len(testing_data)):
    y_pred.append(classifier.classify_many(testing_data[i]))

# %%
y_pred
# Out:
# [['negative'],
#  ['negative'],
#  ['negative'],
#  ['neutral'],
#  ['positive'],
#  ['negative'],
#  ['neutral'],
#  ['negative'],
#  ['negative'],
#  ['negative'],
#  ['negative'],
#  ['negative'],
#  ['neutral'],
#  ['negative'],
#  ['neutral'],
#  ['negative'],
#  ['positive'],
#  ['neutral'],
#  ['negative'],
#  ['negative'],
#  ['positive'],
#  ['neutral'],
#  ['negative'],
#  ['negative'],
#  ['negative'],
#  ['neutral'],
#  ['negative'],
#  ['negative'],
#  ['neutral'],
#  ['negative'],
#  ['negative'],
#  ['neutral'],
#  ['negative'],
#  ['negative'],
#  ['negative'],
#  ['negative'],
#  ['negative'],
#  ['negative'],
#  ['negative'],
#  ['negative'],
#  ['positive'],
#  ['negative'],
#  ['negative'],
#  ['positive'],
#  ['negative'],
#  ['negative'],
#  ['negative'],
#  ['negative'],
#  ['neutral'],
#  ['neutral'],
#  ['neutral'],
#  ['negative'],
#  ['negative'],
#  ['positive'],
#  ['negative'],
#  ['negative'],
#  ['negative'],
#  ['positive'],
#  ['positive'],
# ...

# %%
np.savetxt("Y_pred_naive_1.csv", y_pred, delimiter=",", fmt="%s")

# %% [markdown]
# # random forest

# %%
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=20, n_jobs=-1)
clf_rf = SklearnClassifier(rf)

# %%
clf_rf.train(training_data)
# Out:
# <SklearnClassifier(RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False))>

# %%
y_pred2 = []
for i in range(len(testing_data)):
    y_pred2.append(clf_rf.classify_many(testing_data[i]))

# %%
np.savetxt("Y_pred_rf_2.csv", y_pred2, delimiter=",", fmt="%s")

# %% [markdown]
# # SVM

# %%
from sklearn import svm

# %%
clf = svm.SVC(C=700, gamma=0.0001, kernel="linear")

# %%
clf_svm = SklearnClassifier(clf)

# %%
clf_svm.train(training_data)

# %%
y_pred3 = []
for i in range(len(testing_data)):
    y_pred3.append(clf_svm.classify_many(testing_data[i]))

# %%
np.savetxt("Y_pred_svm_2.csv", y_pred3, delimiter=",", fmt="%s")

# %%
#c=800, gamma=0.0001, score = .7809
#c=700, score = .7814
